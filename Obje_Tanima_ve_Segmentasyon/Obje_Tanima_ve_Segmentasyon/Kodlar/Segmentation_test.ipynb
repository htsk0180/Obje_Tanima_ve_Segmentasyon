# %%
# !git clone https://github.com/CSAILVision/semantic-segmentation-pytorch.git
# %cd semantic-segmentation-pytorch
# !python setup.py install

# %%
# !chmod +x demo_test.sh
# !./demo_test.sh

# %%
# !python3 -u test.py --imgs adana.jpg --gpu 0 --cfg config/ade20k-resnet50dilated-ppm_deepsup.yaml

# %%
from IPython.display import display
from PIL import Image
display(Image.open("adana.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2560x640 at 0x7F8F5FACF710>
